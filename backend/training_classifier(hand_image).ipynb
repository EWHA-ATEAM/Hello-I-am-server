# %%
import os

train_hi_dir = os.path.join('/content/drive/MyDrive/dataset/train/hi')
train_heart_dir = os.path.join('/content/drive/MyDrive/dataset/train/heart')
train_pet_dir = os.path.join('/content/drive/MyDrive/dataset/train/pet')

train_hi_files = os.listdir(train_hi_dir)
train_heart_files = os.listdir(train_heart_dir)
train_pet_files = os.listdir(train_pet_dir)

print('total num of training hi images:', len(train_hi_files))
print('total num of training heart images:', len(train_heart_files))
print('total num of training pet images:', len(train_pet_files))

print(train_hi_files[:10])
print(train_heart_files[:10])
print(train_pet_files[:10])
# Out:
# total num of training hi images: 961
# total num of training heart images: 959
# total num of training pet images: 973
# ['IMG_6886.jpg', 'IMG_6885.jpg', 'IMG_6883.jpg', 'IMG_6884.jpg', 'IMG_6889.jpg', 'IMG_6887.jpg', 'IMG_6888.jpg', 'IMG_6891.jpg', 'IMG_6893.jpg', 'IMG_6890.jpg']
# ['KakaoTalk_20220305_205656630.jpg', 'KakaoTalk_20220305_205658658.jpg', 'KakaoTalk_20220305_205657105.jpg', 'KakaoTalk_20220305_205659181.jpg', 'KakaoTalk_20220305_205701290.jpg', 'KakaoTalk_20220305_205659711.jpg', 'KakaoTalk_20220305_205700760.jpg', 'KakaoTalk_20220305_205702855.jpg', 'KakaoTalk_20220305_205701840.jpg', 'KakaoTalk_20220305_205703381.jpg']
# ['IMG_7335.JPG', 'IMG_7340.JPG', 'IMG_7342.JPG', 'IMG_7345.JPG', 'IMG_7344.JPG', 'IMG_7336.JPG', 'IMG_7346.JPG', 'IMG_7343.JPG', 'IMG_7341.JPG', 'IMG_7347.JPG']

# %%
import tensorflow as tf
import keras_preprocessing
from keras_preprocessing import image
from keras_preprocessing.image import ImageDataGenerator

TRAINING_DIR = "/content/drive/MyDrive/dataset/train/"
training_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range=40,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest')


VALIDATION_DIR = "/content/drive/MyDrive/dataset/validation/"
validation_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = training_datagen.flow_from_directory(
TRAINING_DIR,
target_size=(150, 150),
class_mode='categorical',
batch_size=80
)

validation_generator = validation_datagen.flow_from_directory(
VALIDATION_DIR,
target_size=(150, 150),
class_mode='categorical',
batch_size=80
)

model = tf.keras.models.Sequential([
  # Note the input shape is the desired size of the image 150x150 with 3 bytes color
  # This is the first convolution
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
  tf.keras.layers.MaxPooling2D(2, 2),
  # The second convolution
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  # The third convolution
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  # The fourth convolution
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  # Flatten the results to feed into a DNN
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dropout(0.5),
  # 512 neuron hidden layer
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(3, activation='softmax')
])


model.summary()

model.compile(loss = 'categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(train_generator, epochs=75, steps_per_epoch=15, validation_data = validation_generator, verbose = 2, validation_steps=3)

model.save("model3.h5")

#로컬에 저장하기
from google.colab import files
files.download('model3.h5')
# Out:
# Found 2893 images belonging to 3 classes.
# Found 149 images belonging to 3 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dropout (Dropout)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 3,473,475
# Trainable params: 3,473,475
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/75
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 3 batches). You may need to use the repeat() function when building your dataset.
# 15/15 - 481s - loss: 1.8168 - accuracy: 0.3327 - val_loss: 1.0977 - val_accuracy: 0.3356 - 481s/epoch - 32s/step
# Epoch 2/75
# 15/15 - 325s - loss: 1.0983 - accuracy: 0.3425 - 325s/epoch - 22s/step
# Epoch 3/75
# 15/15 - 272s - loss: 1.1065 - accuracy: 0.3792 - 272s/epoch - 18s/step
# Epoch 4/75
# 15/15 - 251s - loss: 1.0985 - accuracy: 0.3675 - 251s/epoch - 17s/step
# Epoch 5/75
# 15/15 - 227s - loss: 1.1086 - accuracy: 0.3725 - 227s/epoch - 15s/step
# Epoch 6/75
# 15/15 - 236s - loss: 1.0877 - accuracy: 0.3892 - 236s/epoch - 16s/step
# Epoch 7/75
# 15/15 - 221s - loss: 1.1183 - accuracy: 0.4413 - 221s/epoch - 15s/step
# Epoch 8/75
# 15/15 - 233s - loss: 1.0762 - accuracy: 0.4508 - 233s/epoch - 16s/step
# Epoch 9/75
# 15/15 - 214s - loss: 1.0842 - accuracy: 0.4793 - 214s/epoch - 14s/step
# Epoch 10/75
# 15/15 - 230s - loss: 1.0308 - accuracy: 0.4717 - 230s/epoch - 15s/step
# Epoch 11/75
# 15/15 - 225s - loss: 0.9826 - accuracy: 0.5175 - 225s/epoch - 15s/step
# Epoch 12/75
# 15/15 - 230s - loss: 0.9035 - accuracy: 0.5592 - 230s/epoch - 15s/step
# Epoch 13/75
# 15/15 - 228s - loss: 0.8858 - accuracy: 0.6008 - 228s/epoch - 15s/step
# Epoch 14/75
# 15/15 - 224s - loss: 0.8462 - accuracy: 0.6375 - 224s/epoch - 15s/step
# Epoch 15/75
# 15/15 - 229s - loss: 0.7195 - accuracy: 0.6817 - 229s/epoch - 15s/step
# Epoch 16/75
# 15/15 - 228s - loss: 0.7292 - accuracy: 0.6875 - 228s/epoch - 15s/step
# Epoch 17/75
# 15/15 - 209s - loss: 0.7089 - accuracy: 0.7017 - 209s/epoch - 14s/step
# Epoch 18/75
# 15/15 - 223s - loss: 0.6705 - accuracy: 0.7150 - 223s/epoch - 15s/step
# Epoch 19/75
# 15/15 - 219s - loss: 0.5658 - accuracy: 0.7500 - 219s/epoch - 15s/step
# Epoch 20/75
# 15/15 - 223s - loss: 0.6162 - accuracy: 0.7492 - 223s/epoch - 15s/step
# Epoch 21/75
# 15/15 - 216s - loss: 0.5716 - accuracy: 0.7670 - 216s/epoch - 14s/step
# Epoch 22/75
# 15/15 - 227s - loss: 0.5493 - accuracy: 0.7792 - 227s/epoch - 15s/step
# Epoch 23/75
# 15/15 - 236s - loss: 0.4755 - accuracy: 0.8050 - 236s/epoch - 16s/step
# Epoch 24/75
# 15/15 - 235s - loss: 0.4743 - accuracy: 0.7958 - 235s/epoch - 16s/step
# Epoch 25/75
# 15/15 - 221s - loss: 0.4142 - accuracy: 0.8385 - 221s/epoch - 15s/step
# Epoch 26/75
# 15/15 - 223s - loss: 0.4771 - accuracy: 0.7961 - 223s/epoch - 15s/step
# Epoch 27/75
# 15/15 - 223s - loss: 0.4570 - accuracy: 0.8183 - 223s/epoch - 15s/step
# Epoch 28/75
# 15/15 - 209s - loss: 0.3830 - accuracy: 0.8500 - 209s/epoch - 14s/step
# Epoch 29/75
# 15/15 - 224s - loss: 0.4496 - accuracy: 0.8242 - 224s/epoch - 15s/step
# Epoch 30/75
# 15/15 - 210s - loss: 0.3236 - accuracy: 0.8808 - 210s/epoch - 14s/step
# Epoch 31/75
# 15/15 - 224s - loss: 0.4168 - accuracy: 0.8400 - 224s/epoch - 15s/step
# Epoch 32/75
# 15/15 - 226s - loss: 0.3743 - accuracy: 0.8475 - 226s/epoch - 15s/step
# Epoch 33/75
# 15/15 - 216s - loss: 0.2734 - accuracy: 0.8817 - 216s/epoch - 14s/step
# Epoch 34/75
# 15/15 - 225s - loss: 0.3555 - accuracy: 0.8700 - 225s/epoch - 15s/step
# Epoch 35/75
# 15/15 - 212s - loss: 0.2816 - accuracy: 0.8826 - 212s/epoch - 14s/step
# Epoch 36/75
# 15/15 - 224s - loss: 0.3502 - accuracy: 0.8650 - 224s/epoch - 15s/step
# Epoch 37/75
# 15/15 - 208s - loss: 0.3103 - accuracy: 0.8791 - 208s/epoch - 14s/step
# Epoch 38/75
# 15/15 - 225s - loss: 0.2686 - accuracy: 0.8992 - 225s/epoch - 15s/step
# Epoch 39/75
# 15/15 - 227s - loss: 0.2936 - accuracy: 0.8783 - 227s/epoch - 15s/step
# Epoch 40/75
# 15/15 - 231s - loss: 0.2300 - accuracy: 0.9133 - 231s/epoch - 15s/step
# Epoch 41/75
# 15/15 - 217s - loss: 0.3420 - accuracy: 0.8932 - 217s/epoch - 14s/step
# Epoch 42/75
# 15/15 - 216s - loss: 0.2282 - accuracy: 0.9197 - 216s/epoch - 14s/step
# Epoch 43/75
# 15/15 - 213s - loss: 0.2391 - accuracy: 0.9188 - 213s/epoch - 14s/step
# Epoch 44/75
# 15/15 - 222s - loss: 0.1792 - accuracy: 0.9358 - 222s/epoch - 15s/step
# Epoch 45/75
# 15/15 - 223s - loss: 0.2359 - accuracy: 0.9008 - 223s/epoch - 15s/step
# Epoch 46/75
# 15/15 - 221s - loss: 0.2313 - accuracy: 0.9267 - 221s/epoch - 15s/step
# Epoch 47/75
# 15/15 - 210s - loss: 0.2325 - accuracy: 0.9179 - 210s/epoch - 14s/step
# Epoch 48/75
# 15/15 - 223s - loss: 0.2017 - accuracy: 0.9317 - 223s/epoch - 15s/step
# Epoch 49/75
# 15/15 - 223s - loss: 0.2020 - accuracy: 0.9250 - 223s/epoch - 15s/step
# Epoch 50/75
# 15/15 - 213s - loss: 0.1858 - accuracy: 0.9170 - 213s/epoch - 14s/step
# Epoch 51/75
# 15/15 - 227s - loss: 0.2331 - accuracy: 0.9242 - 227s/epoch - 15s/step
# Epoch 52/75
# 15/15 - 212s - loss: 0.2092 - accuracy: 0.9267 - 212s/epoch - 14s/step
# Epoch 53/75
# 15/15 - 209s - loss: 0.1433 - accuracy: 0.9550 - 209s/epoch - 14s/step
# Epoch 54/75
# 15/15 - 222s - loss: 0.2669 - accuracy: 0.9133 - 222s/epoch - 15s/step
# Epoch 55/75
# 15/15 - 209s - loss: 0.1632 - accuracy: 0.9435 - 209s/epoch - 14s/step
# Epoch 56/75
# 15/15 - 212s - loss: 0.1115 - accuracy: 0.9603 - 212s/epoch - 14s/step
# Epoch 57/75
# 15/15 - 212s - loss: 0.2313 - accuracy: 0.9250 - 212s/epoch - 14s/step
# Epoch 58/75
# 15/15 - 219s - loss: 0.1438 - accuracy: 0.9433 - 219s/epoch - 15s/step
# Epoch 59/75
# 15/15 - 212s - loss: 0.3138 - accuracy: 0.9109 - 212s/epoch - 14s/step
# Epoch 60/75
# 15/15 - 218s - loss: 0.1293 - accuracy: 0.9550 - 218s/epoch - 15s/step
# Epoch 61/75
# 15/15 - 217s - loss: 0.2026 - accuracy: 0.9308 - 217s/epoch - 14s/step
# Epoch 62/75
# 15/15 - 217s - loss: 0.1238 - accuracy: 0.9592 - 217s/epoch - 14s/step
# Epoch 63/75
# 15/15 - 218s - loss: 0.1602 - accuracy: 0.9417 - 218s/epoch - 15s/step
# Epoch 64/75
# 15/15 - 217s - loss: 0.1670 - accuracy: 0.9433 - 217s/epoch - 14s/step
# Epoch 65/75
# 15/15 - 220s - loss: 0.1532 - accuracy: 0.9533 - 220s/epoch - 15s/step
# Epoch 66/75
# 15/15 - 210s - loss: 0.2553 - accuracy: 0.9117 - 210s/epoch - 14s/step
# Epoch 67/75
# 15/15 - 210s - loss: 0.0883 - accuracy: 0.9682 - 210s/epoch - 14s/step
# Epoch 68/75
# 15/15 - 208s - loss: 0.1256 - accuracy: 0.9559 - 208s/epoch - 14s/step
# Epoch 69/75
# 15/15 - 223s - loss: 0.1346 - accuracy: 0.9525 - 223s/epoch - 15s/step
# Epoch 70/75
# 15/15 - 208s - loss: 0.0937 - accuracy: 0.9691 - 208s/epoch - 14s/step
# Epoch 71/75
# 15/15 - 219s - loss: 0.2036 - accuracy: 0.9317 - 219s/epoch - 15s/step
# Epoch 72/75
# 15/15 - 211s - loss: 0.1339 - accuracy: 0.9532 - 211s/epoch - 14s/step
# Epoch 73/75
# 15/15 - 206s - loss: 0.1169 - accuracy: 0.9612 - 206s/epoch - 14s/step
# Epoch 74/75
# 15/15 - 219s - loss: 0.1123 - accuracy: 0.9642 - 219s/epoch - 15s/step
# Epoch 75/75
# 15/15 - 204s - loss: 0.1185 - accuracy: 0.9620 - 204s/epoch - 14s/step

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from keras.preprocessing import image
import numpy as np

model = load_model('/content/drive/MyDrive/model3.h5')
model.summary()

img = image.load_img("/content/drive/MyDrive/pet.jpg", target_size=(150,150))
img2 = image.img_to_array(img)
img2 = np.expand_dims(img2, axis = 0)

predict1 = model.predict(img2)
print("예측값1: ", predict1)

if predict1[0][0]==1: print('heart')
elif predict1[0][1]==1: print('hi')
elif predict1[0][2]==1: print('pet')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dropout (Dropout)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 3,473,475
# Trainable params: 3,473,475
# Non-trainable params: 0
# _________________________________________________________________
# 예측값1:  [[0. 1. 0.]]
# hi
